# %%
#1
n=int(input())
lat=0
while n!=0:
  lat=lat*10+n%10
  lat//=10
print(lat)

# %%
#2
a,b=map(int,input().split())
a=a^b
b=a^b
a=a^b
print(a,b)

# %%
#3
n=int(input())
if n>0 and n&(n-1)==0:
  print("True")
else:
  print("False")

# %%
#4
from math import *
m,n=map(int,input().split())
chia=m/n
print(floor(chia))
# Out:
# 2 3
# 0

# %%
#5
from math import *
m,n=map(int,input().split())
chia=m/n
print(ceil(chia))

# %%
#6
n=int(input())
if n%2==0:
  print("Even")
else:
  print("Odd")

# %%
#7
a,b=map(int,input().split())
if a<0 and b<0:
  print("Yes")
else:
  print("False")

# %%
#8 hàm len() tính tổng kí tự
a,b=map(input().split())
if len(a)>len(b):
  print("True")
else:
  print("False")

# %%
#9
a,b,c=map(int,input().split())
if a>0 and b>0 and c>0 and (a+b>c or b+c>a or c+a>b):
  print("Yes")
else:
  print("False")

# %%
#10
from math import *
a,b,c,d=map(int,input().split())
print(max(a,b,c,d))

# %%
#11
a,b,c=map(int,input().split())
if a>0 and b>0 and c>0 and a==b and b==c:
  print("Tam giác đều")
elif a>0 and b>0 and c>0 and (a==b or b==c or c==a):
  print("Tam giác cân")
elif a>0 and b>0 and c>0 and (a+b>c or b+c>a or c+a>b):
  print("Tam giác thường")
else:
  print("Không phải tam giác!")

# %%
#12
n=int(input())
if n%400==0 or (n%4==0 and n%100!=0):
  print("Yes")
else:
  print("No")

# %%
#13
dien=int(input())
S=0
if dien<=50 and dien>0:
  S=1500*dien
elif dien>50 and dien<=100:
  S=1500*50+(dien-50)*2000
else:
  S=1500*50+(100-50)*2000+3000*(dien-100)
print(S)
# Out:
# 120
# 235000

# %%
#14
a,b=map(float,input().split())
if a==0 and b==0:
  print("Vô số nghiệm")
elif a==0:
  print("Vô nghiệm")
else:
  print("%.2f" %(-b/a))

# %%
#15
tbinh=float(input())
if tbinh >=8.0:
  print("Gioi")
elif tbinh>=6.5 and tbinh<8.0:
  print("Kha")
elif tbinh>=5.0 and tbinh<6.5:
  print("trung binh")
else:
  print("Yeu")

# %%
#16
x=float(input())
i=int(x)
if x>=0:
  down=i
elif x!=i:
  down=i
else:
  down=i-1
if x!=i:
  up=i
else:
  up=i+1
diff=x-i
if x>=0 and diff>=0.5:
  near=i+1
else:
  near=i
if diff<=-0.5:
  near=i-1
else:
  near=i
print(down,up,near)
# Out:
# -2
# -2 -2 -2
