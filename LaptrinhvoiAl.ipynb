# %%
#W1A1
a=7
b=5
c=a-b
print(c)
# Out:
# 2

# %%
#W1A2
city="Hà Nội"
year=2025
print("Thành phố",city,"-Năm",year)
# Out:
# Thành phố Hà Nội -Năm 2025

# %%
#W1A3
n=4
t=0
for i in range(1,n+1):
  t+=i
print(t)
# Out:
# 10

# %%
#W1A4
numbers=[1,2,3,4]
for i in numbers:
  if i%2==0:
    print(i,"là số chẵn")
  else:
    print(i,"là số lẻ")
# Out:
# 1 là số lẻ
# 2 là số chẵn
# 3 là số lẻ
# 4 là số chẵn

# %%
# W1A5
animals=["cat","dog","cat","bird"]
count=0
for i in animals:
  count+=1
print("Số phần tử trong danh sách:",count)
# Out:
# 4

# %%
#W1A6
# === Al Prediction System ===
# 1 Sentiment Analysis
# 2 Weather Forecast
# 3 Exit

# %%
#W1A7
num=int(input("Nhập số:"))
if num%2==0:
  print("Số chẵn")
else:
  print("Số lẻ")
# Out:
# Nhập số:100
# Số chẵn

# %%
#W1A8
for i in range(3):
  print("Al đang học lần",i+1)
  print("Huấn luyện xong!")
# Out:
# Al đang học lần 1
# Huấn luyện xong!
# Al đang học lần 2
# Huấn luyện xong!
# Al đang học lần 3
# Huấn luyện xong!

# %%
#W1A9
for x in ["cat","dog","fish"]:
 print("Dự đoán con vật:",x)
# Out:
# Dự đoán con vật: cat
# Dự đoán con vật: dog
# Dự đoán con vật: fish

# %%
#W1A10
print("===Al Prediction System===")
print("1) Sentiment Analysis")
print("2) Weather Fỏecast")
print("3) Exit")
print("Please choose an option:")
# Out:
# ===Al Prediction System
# 1) Sentiment Analysis
# 2) Weather Fỏecast
# 3) Exit
# Please choose an option:
