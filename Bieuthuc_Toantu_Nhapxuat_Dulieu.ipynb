# %%
#W2A1
print("Hello world!")
# Out:
# Hello world!

# %%
#W2A2
n=input()
print("Chào",n)

# %%
#W2A3
a,b=map(int,input().split())
c=a/b
print(a+b)
print(a-b)
print(a*b)
print(a%b)
print(a//b)
print("%.2f" % c)
# Out:
# 3456  233
# 3689.0
# 3223.0
# 805248.0
# 194.0
# 14.0
# 14.83

# %%
#W2A4
a1,b1,c1,a2,b2,a3=map(int,input().split())
tbinh=(a1+b1+c1+a2*2+b2*2+a3*3)/10
print("%.1f" % tbinh)
# Out:
# 3 4 5 6 7 8
# 6.2

# %%
#W2A5
a,b=map(int,input().split())
print(a**b)
# Out:
# 4 5
# 1024

# %%
#W2A6
c=input()
thuong=ord(c)
print(chr(thuong).upper())
# Out:
# d
# D

# %%
#W2A7
A=((13*2)*3+5)
B=13**2*3+5

# %%
#W2A8
C=int(input())
F=9/5*C+32
print("%.2f" %F)
# Out:
# 23
# 73.40

# %%
#W2A9
x=float(input())
S=10+1.4*x
print('%.2f' % S)
# Out:
# 1
# 11.40

# %%
#W2A10
a,b,c=input().split()
a,b,c=c,b,a
print(a,b,c)
# Out:
# 1 2 3
# 3 2 1

# %%
#W2A11
h,m=map(int,input().split())
s=(h*60+m)*60
print(s)
# Out:
# 1 20
# 4800

# %%
#W2A12
n=int(input())
dan=n*6
print(dan)

# %%
#W2A13
a,b=map(int,input().split())
donvi=(a*b)%10
print(donvi)
# Out:
# 4 3
# 2

# %%
#W2A14
a,b=map(int,input().split())
a,b=b,a
print(a,b)

# %%
#W2A15
n=int(input())
sao=3*n*(n-1)+1
print(sao)

# %%
#W2A16
print("Spring\nSummer\nFall\nWinter")

# %%
#W2A17
print("*")
print("***")
print("*****")

# %%
#W2A18
print("### # #  ### ###")
print(" #  #  #  #   #")
print(" #  #   # #   #")
print(" #  #  #  #   #")
print(" #  # #   #   #")

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday,Tuesday,Wednesday,Thursday,Friday,Saturday,Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December
